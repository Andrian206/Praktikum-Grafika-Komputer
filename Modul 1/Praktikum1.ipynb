# %%
print("Selamat Belajar Python")
# Out:
# Selamat Belajar Python

# %%
# ini adalah komentar
print("Selamat Belajar Python")
print("Di Lab Fakultas Ilmu Komputer Universitas Kuningan") # ini juga komentar
# printLn("statement ini tidak akan dipanggil")
# Out:
# Selamat Belajar Python
# Di Lab Fakultas Ilmu Komputer Universitas Kuningan

# %%
nama = "Tito Sugiharto"
hobi = 'Membaca'
umur = 40
laki = True

print("===== biodata =====")
print("nama: %s" % (nama))
print("hobi: %s, umur: %d, laki: %r" % (hobi, umur, laki))
# Out:
# ===== biodata =====
# nama: Tito Sugiharto
# hobi: Membaca, umur: 40, laki: True

# %%
import matplotlib.pyplot as plt

# Tentukan ukuran canvas
canvas_width = 10
canvas_height = 10

# Membuat canvas kosong dengan latar belakang putih
canvas = plt.figure(figsize=(canvas_width, canvas_height))
ax = canvas.add_subplot(111)

# Matikan axis (sumbu)
ax.axis('off')

# Gambar titik piksel di koordinat (5, 5)
ax.plot(5, 5, 'ro') # 'ro' berarti titik merah (red circle)

# Tampilkan gambar
plt.show()

# %%
import matplotlib.pyplot as plt   # Import library matplotlib untuk menggambar grafik

canvas_width = 8   # Lebar kanvas
canvas_height = 8  # Tinggi kanvas

canvas = plt.figure(figsize=(canvas_width, canvas_height))  # Membuat kanvas ukuran 8x8
ax = canvas.add_subplot(111)  # Menambahkan bidang gambar (subplot) ke kanvas

x1 = [1, 8]   # Titik awal dan akhir garis pertama (sumbu X)
y1 = [1, 7]   # Titik awal dan akhir garis pertama (sumbu Y)
ax.plot(x1, y1, 'ro-')  # Gambar garis merah dengan titik bulat ('r' = red, 'o' = bulat, '-' = garis)

x1 = [2, 7]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [1, 8]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'bo-')  # Gambar garis biru dengan titik bulat ('b' = blue)

ax.grid(True, linestyle='--', color='gray', alpha=0.7)  # Menampilkan garis bantu (grid) putus-putus

ax.set_xlabel('Sumbu X')  # Memberi label pada sumbu X
ax.set_ylabel('Sumbu Y')  # Memberi label pada sumbu Y

ax.set_xlim(0, 9)  # Menentukan batas tampilan sumbu X dari 0 sampai 9
ax.set_ylim(0, 9)  # Menentukan batas tampilan sumbu Y dari 0 sampai 9

plt.show()  # Menampilkan hasil gambar di layar

# %%
import matplotlib.pyplot as plt   # Import library matplotlib untuk menggambar grafik

canvas_width = 8   # Lebar kanvas
canvas_height = 8  # Tinggi kanvas

canvas = plt.figure(figsize=(canvas_width, canvas_height))  # Membuat kanvas ukuran 8x8
ax = canvas.add_subplot(111)  # Menambahkan bidang gambar (subplot) ke kanvas

x1 = [1, 8]   # Titik awal dan akhir garis pertama (sumbu X)
y1 = [1, 1]   # Titik awal dan akhir garis pertama (sumbu Y)
ax.plot(x1, y1, 'ro-')  # Gambar garis merah dengan titik bulat ('r' = red, 'o' = bulat, '-' = garis)

x1 = [1, 1]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [8, 1]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'bo-')  # Gambar garis biru dengan titik bulat ('b' = blue)

x1 = [1, 8]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [8, 8]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'mo-')  # Gambar garis magenta dengan titik bulat ('m' = magenta)

x1 = [8, 8]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [8, 1]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'go-')  # Gambar garis hijau dengan titik bulat ('g' = green)

# Dalam
x1 = [2, 7]   # Titik awal dan akhir garis pertama (sumbu X)
y1 = [2, 2]   # Titik awal dan akhir garis pertama (sumbu Y)
ax.plot(x1, y1, 'co-')  # Gambar garis cyan dengan titik bulat ('c' = cyan, 'o' = bulat, '-' = garis)

x1 = [2, 2]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [7, 2]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'go-')  # Gambar garis hijau dengan titik bulat ('g' = green)

x1 = [2, 7]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [7, 7]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'yo-')  # Gambar garis kuning dengan titik bulat ('y' = yellow, 'o' = bulat, '-' = garis)

x1 = [7, 7]   # Titik awal dan akhir garis kedua (sumbu X)
y1 = [7, 2]   # Titik awal dan akhir garis kedua (sumbu Y)
ax.plot(x1, y1, 'bo-')  # Gambar garis biru dengan titik bulat ('b' = blue)

ax.grid(True, linestyle='--', color='gray', alpha=0.7)  # Menampilkan garis bantu (grid) putus-putus

ax.set_xlabel('Sumbu X')  # Memberi label pada sumbu X
ax.set_ylabel('Sumbu Y')  # Memberi label pada sumbu Y

ax.set_xlim(0, 9)  # Menentukan batas tampilan sumbu X dari 0 sampai 9
ax.set_ylim(0, 9)  # Menentukan batas tampilan sumbu Y dari 0 sampai 9

plt.show()  # Menampilkan hasil gambar di layar
