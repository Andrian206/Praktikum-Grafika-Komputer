# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Membuat sebuah figure dan axis
fig, ax = plt.subplots()

# Fungsi untuk menggambar lingkaran
def gambar_lingkaran(radius):
    """
    Menggambar lingkaran dengan radius yang ditentukan oleh parameter 'radius'.

    Parameter:
    radius (int): Radius lingkaran.
    """
    # Menggambar lingkaran dengan radius tertentu
    lingkaran = patches.Circle((0, 0), radius, edgecolor='blue', facecolor='none', linewidth=2)
    ax.add_patch(lingkaran)

    # Mengatur batas-batas tampilan sumbu agar sesuai dengan radius lingkaran
    ax.set_xlim(-radius - 10, radius + 10)
    ax.set_ylim(-radius - 10, radius + 10)

    # Menampilkan grid dan lingkaran
    plt.grid(True)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

# Memanggil fungsi untuk menggambar lingkaran dengan radius 50 unit
gambar_lingkaran(50)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Membuat sebuah figure dan axis
fig, ax = plt.subplots()

# Fungsi untuk menggambar segitiga
def gambar_segitiga(panjang_sisi):
    # Menghitung koordinat titik-titik segitiga
    t1 = (0, 0)
    t2 = (panjang_sisi, 0)
    # Tinggi segitiga sama sisi
    tinggi = panjang_sisi * (3 ** 0.5) / 2
    t3 = (panjang_sisi / 2, tinggi)
    
    koordinat_titik = [t1, t2, t3]

    # Membuat objek segitiga dengan koordinat yang dihitung
    segitiga = patches.Polygon(koordinat_titik, closed=True, edgecolor='blue', facecolor='none', linewidth=2)
    ax.add_patch(segitiga)

    # Mengatur batas-batas tampilan sumbu agar sesuai dengan ukuran segitiga
    ax.set_xlim(-10, panjang_sisi + 10)
    ax.set_ylim(-10, tinggi + 10)

    # Menampilkan grid dan segitiga
    plt.grid(True)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

# Memanggil fungsi untuk menggambar segitiga dengan panjang sisi 100 unit
gambar_segitiga(100)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Membuat sebuah figure dan axis
fig, ax = plt.subplots()

# Fungsi untuk menggambar persegi panjang
def gambar_persegi_panjang(lebar, tinggi):
    """
    Menggambar persegi panjang dengan lebar dan tinggi yang ditentukan.

    Parameter:
    lebar (int): Lebar persegi panjang.
    tinggi (int): Tinggi persegi panjang.
    """
    # Membuat objek persegi panjang (dimulai dari (0, 0) dengan lebar dan tinggi tertentu)
    persegi_panjang = patches.Rectangle((0, 0), lebar, tinggi, edgecolor='blue', facecolor='none', linewidth=2)
    ax.add_patch(persegi_panjang)

    # Mengatur batas-batas tampilan sumbu agar sesuai dengan ukuran persegi panjang
    ax.set_xlim(-10, lebar + 10)
    ax.set_ylim(-10, tinggi + 10)

    # Menampilkan grid dan persegi panjang
    plt.grid(True)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

# Memanggil fungsi untuk menggambar persegi panjang dengan lebar 100 unit dan tinggi 50 unit
gambar_persegi_panjang(100, 50)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Membuat sebuah figure dan axis
fig, ax = plt.subplots()

# Fungsi untuk menggambar kotak
def gambar_kotak(ukuran):
    """
    Menggambar kotak dengan panjang sisi yang ditentukan oleh parameter 'ukuran'.

    Parameter:
    ukuran (int): Panjang sisi kotak.
    """
    # Menggambar persegi dengan ukuran tertentu (kotak adalah persegi panjang dengan lebar=tinggi)
    kotak = patches.Rectangle((0, 0), ukuran, ukuran, edgecolor='blue', facecolor='none', linewidth=2)
    ax.add_patch(kotak)

    # Mengatur batas-batas tampilan sumbu agar sesuai dengan ukuran kotak
    ax.set_xlim(-10, ukuran + 10)
    ax.set_ylim(-10, ukuran + 10)

    # Menampilkan grid dan kotak
    plt.grid(True)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

# Memanggil fungsi untuk menggambar kotak dengan ukuran sisi 100 unit
gambar_kotak(100)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig, ax = plt.subplots()

def gambar_segitiga(panjang_sisi):

    t1 = (5, 5)
    t2 = (panjang_sisi + 5, 5)

    tinggi = panjang_sisi * (3 ** 0.5) / 2
    t3 = (panjang_sisi / 2 + 5, tinggi + 5)

    koordinat_titik = [t1, t2, t3]

    segitiga = patches.Polygon(koordinat_titik, closed=True, edgecolor='red', facecolor='none', linewidth=1)
    ax.add_patch(segitiga)

    ax.set_xlim(0, panjang_sisi + 10)
    ax.set_ylim(0, tinggi + 10)

    plt.grid(True)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.show()

gambar_segitiga(10)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig, ax = plt.subplots()
max_x = 0
max_y = 0

def gambar_persegi_panjang(x_awal, y_awal, lebar, tinggi, warna):
    global max_x, max_y

    persegi_panjang = patches.Rectangle((x_awal, y_awal), lebar, tinggi, edgecolor=warna, facecolor='none', linewidth=3)
    ax.add_patch(persegi_panjang)

    max_x = max(max_x, x_awal + lebar)
    max_y = max(max_y, y_awal + tinggi)

gambar_persegi_panjang(20, 10, 40, 45, 'green')
gambar_persegi_panjang(0, 0, 40, 45, 'blue')

ax.set_xlim(-20, max_x + 20)
ax.set_ylim(-10, max_y + 10)

plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

fig, ax = plt.subplots()
max_x = 0
max_y = 0

def gambar_persegi_panjang(x_awal, y_awal, lebar, tinggi, warna):
    global max_x, max_y

    persegi_panjang = patches.Rectangle((x_awal, y_awal), lebar, tinggi, edgecolor=warna, facecolor=warna, linewidth=3)
    ax.add_patch(persegi_panjang)

    max_x = max(max_x, x_awal + lebar)
    max_y = max(max_y, y_awal + tinggi)

gambar_persegi_panjang(0, 1, 9, 3, 'red')
gambar_persegi_panjang(2.2, 3.4, 5, 1.8, 'black')
gambar_persegi_panjang(0, 2.7, 0.9, 0.4, 'yellow')

roda_depan = patches.Circle((2.6, 0.83), 0.8, linewidth=5, edgecolor='black', facecolor='white')
ax.add_patch(roda_depan)

roda_depan = patches.Circle((7.1, 0.83), 0.8, linewidth=5, edgecolor='black', facecolor='white')
ax.add_patch(roda_depan)

ax.set_xlim(-2, max_x + 4)
ax.set_ylim(-2, max_y + 4)

plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()
